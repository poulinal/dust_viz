# %% [markdown]
# # dust_viz worksheet

# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %%
# %pip install ipympl
# %pip install --upgrade ipympl jupyterlab
import matplotlib
# %matplotlib widget
print(matplotlib.get_backend())  # Should show 'TkAgg', 'Qt5Agg', or 'module://ipympl.backend_nbagg'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached jupyterlab-4.5.0-py3-none-any.whl.metadata (16 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# module://ipympl.backend_nbagg

# %% [markdown]
# module load job-assist //
# job-assist
#
# mprof run make_all_density_maps.py
#
# mprof plot --output memory_profile_plot.png

# %%
haloNum = 0  # Change this to the halo number you want to download

# %%
explorer_prefix = "../../../../scratch/poulin.al/dust/data/density_maps/boundparts/"

# %%
data_dir = '/home/poulin.al/git/dust_viz/data/'
point_data_dir = 'points/'

# %% [markdown]
# # get api data

# %%
import iapi_TNG as iapi
import h5py
import numpy as np

#construct url for halo cutout
#Replace [HALO_ID] with the index into the FoF catalog for the halo of interest
# halo_cutout_url = 'http://www.tng-project.org/api/TNG300-1/snapshots/99/halos/[HALO_ID]/cutout.hdf5' 
halo_cutout_url = f'http://www.tng-project.org/api/TNG300-1/snapshots/99/halos/{haloNum}/cutout.hdf5'

# Build the request for the parameters of interest, these are the ones that are in the particle files I have
# We probably won't use all of them, so for quicker testing you can just grab the most important ones: 'Coordinates,Density,Masses,GFM_Metallicity,GFM_Metals,NeutralHydrogenAbundance,ElectronAbundance,StarFormationRate'
#Don't ask me why the request is formatted like this, it has something to do with the URL/HDF5 request and it will break if there are any spaces
params={'gas':'Coordinates,Density,ElectronAbundance,GFM_AGNRadiation,GFM_CoolingRate,GFM_Metallicity,GFM_Metals,GFM_MetalsTagged,InternalEnergy,MagneticField,Masses,NeutralHydrogenAbundance,ParticleIDs,StarFormationRate,Potential,SubfindHsml',}



#Download the cutout
#fName is the name the file will save to, get() automatically appends '.hdf5' extension
# data_dir = '/Users/alexpoulin/Downloads/git/dust_viz/data/'  # Change this to your desired directory
fName = f'{data_dir}halo_{haloNum}'

#check if the hdf5 was downloaded already
#check fname.hdf5 exists
import os
skip = False  # Flag to skip downloading if the file is valid
if os.path.exists(fName+'.hdf5'):
    print(f"File {fName}.hdf5 already exists. Checking if it is not corrupted.")
    #try to open the file, if it fails, download it again
    try:
        with h5py.File(fName+'.hdf5', 'r') as f:
            print("File is valid and not corrupted.")
            skip = True  # Set skip to True if the file is valid
    except OSError:
        print("File is corrupted. Downloading again.")
else:
    #if it doesn't exist, download it
    print(f"Downloading cutout to {fName}.hdf5")
    
if not skip:    
    cutout = iapi.get(halo_cutout_url, params = params, fName = fName)
    print(f"Successfully downloaded cutout")
else:
    print(f"Cutout already exists and is valid")
    

    #To read the files
with h5py.File(fName+'.hdf5', 'r') as f:
    #Load a parameter from the file, use [:] to make the hdf5 dataset act like a normal array (not totally sure why tbh)
    coordinates = f['PartType0']['Coordinates'][:] #'PartType0' means gas particles
    #or use np.asarray
    # masses = np.asarray(f['PartType0']['Masses'])
    # print(f['PartType0']['SubfindHsml'][:]) 
    
    #print all the keys for PartType0
    # print(f['PartType0'].keys())
# else:


# #save group catalog
# if os.
# group_url = f"http://www.tng-project.org/api/TNG300-1/snapshots/99/halos/{haloNum}/"
# group_data = iapi.get(group_url)

# %%
with h5py.File(fName+'.hdf5', 'r') as f:
    print(f.keys())
    print(f['Header'].keys())

# %%
print('Coordinates shape:', coordinates.shape)
print(coordinates[0])

# %% [markdown]
# ## svae group data

# %%
sim = 'TNG300-1'
group_R200Crit=iapi.getHaloField('Group_R_Crit200',simulation=sim, rewriteFile=0, fileName=f'data/groupR200/tempCat_groupR200c')
print(f"Group R200c: {group_R200Crit}")

# %%
sim = 'TNG300-1'
group_pos=iapi.getHaloField('GroupPos',simulation=sim, rewriteFile=0, fileName=f'data/groupR200/tempCat_groupPos')
print(f"Group pos: {group_pos}")

# %% [markdown]
# ## make density maps

# %%
from make_all_density_maps import make_all_maps

make_all_maps()

# %% [markdown]
# # some constants

# %% [markdown]
# # Get density map data
# particle_info_file has columns of [star_pos, hvals_to_star_pos, star_mass, radlist, gal_center_list_1, gal_center_list_2, gal_center_list_3]
#
# stellar_mass_density_map_file has density_mesh which is a 3 dim array to density mass

# %%
particle_info_file = "particle_info_subID_"+str(haloNum)

stellar_mass_density_map_file = "stellar_mass_density_map_subID_"+str(haloNum)

# %%
# %ls '{explorer_prefix}{stellar_mass_density_map_file}.npy'
# %pwd
# %ls "../../../../scratch/poulin.al/dust/data/density_maps/boundparts"
# Out:
# ../../../../scratch/poulin.al/dust/data/density_maps/boundparts/stellar_mass_density_map_subID_0.npy
# particle_info_subID_0.hdf5  stellar_mass_density_map_subID_0.hdf5
# particle_info_subID_0.npy   stellar_mass_density_map_subID_0.npy

# %%
import os
import numpy as np
import h5py

##load npy
# check file exists
# if not os.path.exists(explorer_prefix + particle_info_file + ".npy"):
#     raise FileNotFoundError(f"{explorer_prefix + particle_info_file}. npy not found.")
# if not os.path.exists(explorer_prefix + stellar_mass_density_map_file + ".npy"):
#     raise FileNotFoundError(f"{explorer_prefix + stellar_mass_density_map_file}.npy not found.")

# # read from the numpy file
# particle_info_ = np.load(explorer_prefix+particle_info_file+".npy", allow_pickle=True)
# stellar_mass_density_map_ = np.load(explorer_prefix+stellar_mass_density_map_file+".npy", allow_pickle=True)

#load h5py
# Load particle_info_ from HDF5
with h5py.File(explorer_prefix + particle_info_file + ".hdf5", "r") as f:
    particle_info_ = f['particle_info'][:]

# Load stellar_mass_density_map_ from HDF5
with h5py.File(explorer_prefix + stellar_mass_density_map_file + ".hdf5", "r") as f:
    stellar_mass_density_map_ = f['density_mesh'][:]


print(f"particle_info_ shape: {particle_info_.shape}")
print(f"particle_info_ dtype: {particle_info_.dtype}")
print(f"stellar_mass_density_map_ shape: {stellar_mass_density_map_.shape}")
print(f"stellar_mass_density_map_ dtype: {stellar_mass_density_map_.dtype}")
# Out:
# particle_info_ shape: (20965252, 9)
# particle_info_ dtype: float64
# stellar_mass_density_map_ shape: (2198, 2198, 2198)
# stellar_mass_density_map_ dtype: float64

# %%
#checl memory size
# %whos
# Out:
# Variable                        Type             Data/Info
# ----------------------------------------------------------
# NamespaceMagics                 MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# data_dir                        str              /home/poulin.al/git/dust_viz/data/
# explorer_prefix                 str              ../../../../scratch/pouli<...>/density_maps/boundparts/
# f                               File             <Closed HDF5 file>
# get_ipython                     function         <function get_ipython at 0x149c26682b60>
# h5py                            module           <module 'h5py' from '/sha<...>ckages/h5py/__init__.py'>
# haloNum                         int              0
# json                            module           <module 'json' from '/sha<...>on3.12/json/__init__.py'>
# matplotlib                      module           <module 'matplotlib' from<...>/matplotlib/__init__.py'>
# ...

# %% [markdown]
# # Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from scipy.stats import gaussian_kde
import matplotlib.gridspec as gridspec
from scipy.interpolate import griddata

# %%
# Extract z-slice
# z_slice_idx = stellar_mass_density_map_.shape[2] // 2
# z_slice_position = coords_1d[z_slice_idx]  # physical z-coordinate of slice
num_points = stellar_mass_density_map_.shape[0]
mid = num_points // 2 # we assume square box
density_slice_z = stellar_mass_density_map_[:, :, mid]
density_slice_x = stellar_mass_density_map_[mid, :, :]
density_slice_y = stellar_mass_density_map_[:, mid, :]

# Downsample using slicing (fast, no interpolation)
# step = stellar_mass_density_map_.shape[2] // 32  # adjust 32 to get ~1000 points
# density_2d = density_slice[::step, ::step] #1000 points
# density_2d = density_slice # all points

# Create corresponding coordinate grids
box_size = 3  # your simulation box #grid_length
with h5py.File(explorer_prefix + particle_info_file + ".hdf5", "r") as f:
    N_cell_per_side = f['N_cells_per_side'][()]
    print(N_cell_per_side)
    cell_length = f['cell_length'][()]
    print(cell_length)
    star_pos = f['star_pos'][()]


box_size = N_cell_per_side #* cell_length
    
    
# n_points = density_2d.shape[0]
coords_1d = np.linspace(-box_size/2, box_size/2, num_points)#[::step] #uncomment to downsample
# Out:
# 2198
# 3

# %%
print(star_pos.shape)

# Calculate distance from origin for each point
distances = np.linalg.norm(star_pos, axis=1)  # sqrt(x^2 + y^2 + z^2)

# Find indices of min/max
min_idx = np.argmin(distances)
max_idx = np.argmax(distances)

# Get the points
closest_point = star_pos[min_idx]
farthest_point = star_pos[max_idx]

print(f"Closest: {closest_point} at distance {distances[min_idx]:.3f}")
print(f"Farthest: {farthest_point} at distance {distances[max_idx]:.3f}")

# Overall range
print(f"Distance range: {distances.min():.3f} to {distances.max():.3f}")
# Out:
# (20965252, 3)
# Closest: [ 0.59360621 -0.78180176  1.25615835] at distance 1.594
# Farthest: [ 3209.62980106  3284.39094481 -3282.20554557] at distance 5644.628
# Distance range: 1.594 to 5644.628

# %%
# X, Y = np.meshgrid(coords_1d, coords_1d)
# X_3d, Y_3d, Z_3d = np.meshgrid(coords_1d, coords_1d, coords_1d, indexing='ij') #3d grid #overkill
# Create only 2D grids for each slice
X_xy, Y_xy = np.meshgrid(coords_1d, coords_1d)
X_xz, Z_xz = np.meshgrid(coords_1d, coords_1d)  
Y_yz, Z_yz = np.meshgrid(coords_1d, coords_1d)

# densityMap = (X, Y, density_2d)

# %%
from testPlots import plot_3d_isosurfaces, plot_density_topography, plot_density_topography_3_proj, plot_density_topography_interactive

# thousandTuple = (x,y,z,stellar_mass_density_map_)
# nonzeroThousandTuple = (x_nonzero, y_nonzero, z_nonzero, stellar_mass_density_map__nonzero)

# isosurfaceFig = plot_3d_isosurfaces(densityMap = nonzeroThousandTuple)
# isosurfaceFig.savefig('density_plot.png', dpi=300, bbox_inches='tight')
# %matplotlib inline
# print(f"{X.shape}, {Y.shape}, {densityMap}")
# densityTopographyFig = plot_density_topography(densityMap = (x_flat,y_flat,density_2d))
densityTopographyFigZ = plot_density_topography(densityMap = (X_xy,Y_xy,density_slice_z), labelX="X", labelY="Y")
densityTopographyFigZ.savefig('topographyIsoDensityZ.png', dpi=300, bbox_inches='tight')

densityTopographyFigX = plot_density_topography(densityMap = (Y_yz,Z_yz,density_slice_x), labelX="Y", labelY="Z")
densityTopographyFigX.savefig('topographyIsoDensityX.png', dpi=300, bbox_inches='tight')

densityTopographyFigY = plot_density_topography(densityMap = (X_xz,Z_xz,density_slice_y), labelX="X", labelY="Z")
densityTopographyFigY.savefig('topographyIsoDensityY.png', dpi=300, bbox_inches='tight')

# %matplotlib widget
# Out:
# /home/poulin.al/git/dust_viz/testPlots.py:52: RuntimeWarning: divide by zero encountered in log10
#   log_density = np.log10(density_2d)
# percentiles: [0.00000000e+00 1.43464390e-12 6.19174917e-12 1.77188322e-11
#  6.34133487e-11 3.79474779e-10]
# max_yz: -5.909856716964183, low_yz: -11.707413173931139
# percentiles: [0.00000000e+00 8.19895812e-14 2.96847579e-12 8.45950994e-12
#  2.28730100e-11 7.44768256e-11 3.92983243e-10]
# max_yz: -6.504290851729817, low_yz: -11.82061269321564
# percentiles: [0.00000000e+00 2.74615232e-12 1.45910181e-11 6.19002279e-11
#  4.68788868e-10]
# max_yz: -5.833803182235271, low_yz: -11.609834766780944

# %%
# print(X)
# print(Y)
# print(Z)
print(np.nonzero(density_slice_x))
print(np.nonzero(density_slice_y))
print(np.nonzero(density_slice_z))
log_density_X = np.log10(density_slice_x)
print(log_density_X[(log_density_X!=0) & (~np.isnan(log_density_X)) & np.isfinite(log_density_X)])
print(np.max(density_slice_x))
print(np.nanpercentile(density_slice_x[density_slice_x != 0], 10))
# Out:
# (array([  10,   10,   10, ..., 2197, 2197, 2197]), array([1425, 1426, 1427, ..., 1332, 1333, 1334]))
# (array([  87,   87,   87, ..., 1966, 1966, 1966]), array([918, 919, 920, ..., 636, 637, 638]))
# (array([ 111,  111,  111, ..., 2058, 2058, 2058]), array([1023, 1024, 1025, ..., 2191, 2192, 2193]))
# [-14.75033015 -13.81251489 -13.33303273 ... -11.28683432 -11.31259662
#  -11.36686295]
# 6.234074842944319e-07
# 1.5114274546344174e-12
# /tmp/ipykernel_1247146/1621642697.py:7: RuntimeWarning: divide by zero encountered in log10
#   log_density_X = np.log10(density_slice_x)

# %%
print(f"to plot: {X_xy[0], Y_xy[0], density_slice_x[0]}")
print(f"from partilce_mesh: {stellar_mass_density_map_.shape, stellar_mass_density_map_[(0, 0, 0)]}")
# Out:
# to plot: (array([-1099.        , -1097.99954483, -1096.99908967, ...,
#         1096.99908967,  1097.99954483,  1099.        ]), array([-1099., -1099., -1099., ..., -1099., -1099., -1099.]), array([0., 0., 0., ..., 0., 0., 0.]))
# from partilce_mesh: ((2198, 2198, 2198), 0.0)

# %%
# plot all three projections:

densityTopographyFig3 = plot_density_topography_3_proj(densityMap = (X_xy,Y_xy,X_xz,Z_xz,Y_yz,Z_yz,density_slice_x, density_slice_y, density_slice_z))
densityTopographyFig3.savefig('topographyIsoDensity3.png', dpi=300, bbox_inches='tight')
# Out:
# /home/poulin.al/git/dust_viz/testPlots.py:173: RuntimeWarning: divide by zero encountered in log10
#   log_density_X = np.log10(density_2d_X)
# /home/poulin.al/git/dust_viz/testPlots.py:174: RuntimeWarning: divide by zero encountered in log10
#   log_density_Y = np.log10(density_2d_Y)
# /home/poulin.al/git/dust_viz/testPlots.py:175: RuntimeWarning: divide by zero encountered in log10
#   log_density_Z = np.log10(density_2d_Z)
# max_yz: -7.195633424818727, low_yz: -11.82061269321564
# max_yz: -6.516973098209981, low_yz: -11.609834766780944
# max_yz: -6.665677652241641, low_yz: -11.707413173931139
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(X_xy, Y_xy)
print(stellar_mass_density_map_.shape)
# Out:
# [[-1099.         -1097.99954483 -1096.99908967 ...  1096.99908967
#    1097.99954483  1099.        ]
#  [-1099.         -1097.99954483 -1096.99908967 ...  1096.99908967
#    1097.99954483  1099.        ]
#  [-1099.         -1097.99954483 -1096.99908967 ...  1096.99908967
#    1097.99954483  1099.        ]
#  ...
#  [-1099.         -1097.99954483 -1096.99908967 ...  1096.99908967
#    1097.99954483  1099.        ]
#  [-1099.         -1097.99954483 -1096.99908967 ...  1096.99908967
#    1097.99954483  1099.        ]
#  [-1099.         -1097.99954483 -1096.99908967 ...  1096.99908967
#    1097.99954483  1099.        ]] [[-1099.         -1099.         -1099.         ... -1099.
#   -1099.         -1099.        ]
#  [-1097.99954483 -1097.99954483 -1097.99954483 ... -1097.99954483
#   -1097.99954483 -1097.99954483]
#  [-1096.99908967 -1096.99908967 -1096.99908967 ... -1096.99908967
#   -1096.99908967 -1096.99908967]
#  ...
#  [ 1096.99908967  1096.99908967  1096.99908967 ...  1096.99908967
# ...

# %% [markdown]
# # interactive

# %%
print(N_cell_per_side)
# Out:
# 2198

# %%
plot_density_topography_interactive(stellar_mass_density_map_, N_cell_per_side)
# Out:
# /home/poulin.al/git/dust_viz/testPlots.py:444: RuntimeWarning: divide by zero encountered in log10
#   log_density = np.log10(density_slice)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## OLD

# %%
#grab 1000 random points in coordinates with seed 0
np.random.seed(0)
#this is the random seed, so you can get the same points every time
random_indices = np.random.choice(coordinates.shape[0], 10000, replace=False)
random_num_coordinates = coordinates[random_indices]
#save as a numpy array
np.save(f'{data_dir}{point_data_dir}random_10000_coordinates.npy', random_num_coordinates)
np.save(f'{data_dir}{point_data_dir}random_10000_coordinates.txt', random_num_coordinates)
#save as a .xyz file
with open(f'{data_dir}{point_data_dir}random_10000_coordinates.xyz', 'w') as f:
    for coord in random_num_coordinates:
        f.write(f"{coord[0]} {coord[1]} {coord[2]}\n")

# %%
# Function to create density plot with appropriate opacity
def create_density_plot(x_data, y_data, z_data, thresholds, ax):
    # Calculate point density
    xy = np.vstack([x_data, y_data])
    density = gaussian_kde(xy)(xy)
    
    # Normalize density for colormapping
    norm = Normalize(vmin=min(density), vmax=max(density))
    
    # Create scatter plots for each iso-contour with different opacity
    for i in range(len(thresholds)-1):
        mask = (z_data >= thresholds[i]) & (z_data < thresholds[i+1])
        if i == len(thresholds)-2:
            # Innermost contour - fully opaque
            alpha = 1.0
        else:
            # Outer contours - 80% transparent as per paper
            alpha = 0.2
        
        ax.scatter(x_data[mask], y_data[mask], 
                  c=density[mask], cmap='viridis', 
                  alpha=alpha, edgecolor='none')
    
    # Add gridlines
    ax.grid(True, linestyle='--', alpha=0.7)
    
    # Add markers for galaxies (if coordinates are known)
    # Example: ax.plot(galaxy_x, galaxy_y, 'go', markersize=10)

# %%
# Assuming your data is in a list of (x,y,z) tuples
# Convert to NumPy array for easier manipulation
data = np.array(random_num_coordinates)  # Replace with your actual data
x, y, z = data[:,0], data[:,1], data[:,2]

# Define z-value thresholds for iso-contours (adjust based on your data)
# The paper uses 1.3, 2.5, 3.5, and 6.0 mJy/beam
z_thresholds = [min(z), np.percentile(z, 25), np.percentile(z, 50), 
                np.percentile(z, 75), max(z)]

# Setup figure with grid for the three projections
fig = plt.figure(figsize=(15, 10))
gs = gridspec.GridSpec(2, 2, height_ratios=[1, 1])

# Top projection (x-y)
ax_top = plt.subplot(gs[0, 0])
create_density_plot(x, y, z, z_thresholds, ax_top)
ax_top.set_xlabel('x')
ax_top.set_ylabel('y')

# Front projection (x-z)
ax_front = plt.subplot(gs[1, 0])
create_density_plot(x, z, y, z_thresholds, ax_front)
ax_front.set_xlabel('x')
ax_front.set_ylabel('z')

# Side projection (z-y)
ax_side = plt.subplot(gs[1, 1])
create_density_plot(y, z, x, z_thresholds, ax_side)
ax_side.set_xlabel('y')
ax_side.set_ylabel('z')


#save the figure
plt.savefig('density_projections.png', dpi=300)
plt.tight_layout()
plt.show()

# %%
from mayavi import mlab
import numpy as np

# Assuming your data is in a list of (x,y,z) tuples
data = np.array(random_num_coordinates)
x, y, z = data[:,0], data[:,1], data[:,2]

# Create a 3D density field from the point data
# This is a simplification - you may need more sophisticated binning
xi, yi, zi = np.mgrid[min(x):max(x):100j, min(y):max(y):100j, min(z):max(z):100j]
density = griddata((x, y, z), np.ones_like(x), (xi, yi, zi), method='linear', fill_value=0)

# Create figure
mlab.figure(bgcolor=(1, 1, 1), size=(800, 600))

# Create iso-contours with different opacity
# The paper uses 1.3, 2.5, 3.5, and 6.0 mJy/beam
contour_values = [np.percentile(density[density > 0], p) for p in [25, 50, 75, 90]]

# Create the contours with appropriate opacity
for i, value in enumerate(contour_values):
    if i == len(contour_values) - 1:
        # Innermost contour - fully opaque
        opacity = 1.0
    else:
        # Outer contours - 80% transparent as per paper
        opacity = 0.2
    
    mlab.contour3d(xi, yi, zi, density, contours=[value], opacity=opacity)

# Add markers for galaxies if you have their coordinates
# Example: mlab.points3d(galaxy_x, galaxy_y, galaxy_z, color=(0,1,0), scale_factor=10)

# Setup the view for top-front-side projections
# You'll need to save three different views

mlab.view(azimuth=0, elevation=90)  # Top view
mlab.savefig('top_view.png')

mlab.view(azimuth=0, elevation=0)   # Front view
mlab.savefig('front_view.png')

mlab.view(azimuth=90, elevation=0)  # Side view
mlab.savefig('side_view.png')

mlab.show()
